# %% [markdown]
# <a href="https://colab.research.google.com/github/swathiGangireddy29/vaultcodes/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = """
<!DOCTYPE html> <html> <head> <title>Swathi Gangireddy - Portfolio</title> </head> <body> <h1>Swathi Gangireddy</h1> <section> <h2>About Me</h2> <p> Hello! My name is Swathi Gangireddy. I am a B.Tech student with an interest in programming, data analytics, and web development. I enjoy learning new technologies and building projects that solve real-world problems. My goal is to become a successful software professional. </p> </section> <section> <h2>Skills</h2> <ul> <li>Python Programming</li> <li>HTML & CSS</li> <li>Data Analytics</li> </ul> </section> <section> <h2>Interests</h2> <ol> <li>Machine Learning</li> <li>Web Development</li> <li>Problem Solving</li> </ol> </section> <section> <h2>Projects</h2> <h3>Student Management System</h3> <p> A Python-based application used to manage student records, attendance, and marks efficiently. </p> <a href="#">View Project</a> <h3>Personal Portfolio Website</h3> <p> A simple website developed using HTML to showcase skills, interests, and projects. </p> <a href="#">View Project</a> <h3>Data Analysis Project</h3> <p> Analyzed datasets using Python libraries such as Pandas and NumPy. </p> <a href="#">View Project</a> </section> <section> <h2>Contact Information</h2> <p>Email: swathi@example.com</p> <p> LinkedIn: <a href="https://www.linkedin.com/">LinkedIn Profile</a> </p> <p> GitHub: <a href="https://github.com/">GitHub Profile</a> </p> </section>
"""

HTML(html_content)
# Out:
# <!DOCTYPE html> <html> <head> <title>Swathi Gangireddy - Portfolio</title> </head> <body> <h1>Swathi Gangireddy</h1> <section> <h2>About Me</h2> <p> Hello! My name is Swathi Gangireddy. I am a B.Tech student with an interest in programming, data analytics, and web development. I enjoy learning new technologies and building projects that solve real-world problems. My goal is to become a successful software professional. </p> </section> <section> <h2>Skills</h2> <ul> <li>Python Programming</li> <li>HTML & CSS</li> <li>Data Analytics</li> </ul> </section> <section> <h2>Interests</h2> <ol> <li>Machine Learning</li> <li>Web Development</li> <li>Problem Solving</li> </ol> </section> <section> <h2>Projects</h2> <h3>Student Management System</h3> <p> A Python-based application used to manage student records, attendance, and marks efficiently. </p> <a href="#">View Project</a> <h3>Personal Portfolio Website</h3> <p> A simple website developed using HTML to showcase skills, interests, and proj
# ...
